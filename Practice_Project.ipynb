# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMSkillsNetworkBD0231ENCoursera2789-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# ## Practice Project - Create a machine learning pipeline for a regression project

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# ## Scenario

# %% [markdown]
# You are a data engineer at a data analytics consulting company. Your company prides itself in being able to efficiently handle huge datasets. Data scientists in your office need to work with different algorithms and data in different formats. While they are good at Machine Learning, they count on you to be able do ETL jobs and build ML pipelines.

# %% [markdown]
# ## Objectives
#
# In this 4 part assignment you will:
#
# - Part 1 ETL
#   - Load a csv dataset
#   - Remove duplicates if any
#   - Drop rows with null values if any
#   - Make transformations
#   - Store the cleaned data in parquet format
# - Part 2 Machine Learning Pipeline creation
#   - Create a machine learning pipeline for prediction
# - Part 3 Model evaluation
#   - Evaluate the model using metrics
#   - Print the intercept and the coefficients
# - Part 4 Model Persistance
#   - Cave the model for future production use
#   - Load and verify the stored model

# %% [markdown]
# ## Datasets
#
# In this lab you will be using dataset(s):
#
#  - Modified version of car mileage dataset. Original dataset available at https://archive.ics.uci.edu/ml/datasets/auto+mpg

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`PySpark`](https://spark.apache.org/docs/latest/api/python/index.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMSkillsNetworkBD0231ENCoursera2789-2023-01-01) for connecting to the Spark Cluster

# %% [markdown]
# ### Installing Required Libraries
#
# Spark Cluster is pre-installed in the Skills Network Labs environment. However, you need libraries like pyspark and findspark to
#  connect to this cluster.

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# !pip install pyspark==3.1.2 -q
# !pip install findspark -q

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# FindSpark simplifies the process of using Apache Spark with Python

import findspark
findspark.init()

# %% [markdown]
# ## Part 1 - ETL

# %% [markdown]
# ### Task 1 - Import required libraries

# %%
#your code goes here
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.ml.pipeline import PipelineModel
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import StandardScaler




# import functions/Classes for metrics
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Import all the required libraries
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# from pyspark.sql import SparkSession
# from pyspark.ml import Pipeline
# from pyspark.ml.pipeline import PipelineModel
# from pyspark.ml.feature import VectorAssembler
# from pyspark.ml.regression import LinearRegression
# from pyspark.ml.feature import StringIndexer
# from pyspark.ml.feature import StandardScaler
#
# ```
#
# </details>

# %% [markdown]
# ### Task 2 - Create a spark session

# %%
#Create SparkSession

spark = SparkSession.builder.appName("Practice Project").getOrCreate()  #TODO
# Out:
# 23/12/19 18:25:26 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the SparkSession.builder
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# spark = SparkSession.builder.appName("Practice Project").getOrCreate()
# ```
#
# </details>

# %% [markdown]
# ### Task 3 - Load the csv file into a dataframe

# %% [markdown]
# Download the data file

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-BD0231EN-Coursera/datasets/mpg-raw.csv
# Out:
# --2023-12-19 18:25:45--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-BD0231EN-Coursera/datasets/mpg-raw.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104, 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14354 (14K) [text/csv]
# Saving to: ‘mpg-raw.csv.10’
#
# mpg-raw.csv.10      100%[===================>]  14.02K  --.-KB/s    in 0s
#
# 2023-12-19 18:25:45 (42.4 MB/s) - ‘mpg-raw.csv.10’ saved [14354/14354]

# %% [markdown]
# Load the dataset into the spark dataframe

# %%
# Load dataset
df = spark.read.csv("mpg-raw.csv", header=True, inferSchema=True) #TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use  spark.read.csv
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df = spark.read.csv("mpg-raw.csv", header=True, inferSchema=True)
#
# ```
#
# </details>

# %% [markdown]
# ### Task 4 - Print top 5 rows of the dataset

# %%
#your code goes here

df.show(5)
# Out:
# +----+---------+-----------+----------+------+----------+----+--------+
# | MPG|Cylinders|Engine Disp|Horsepower|Weight|Accelerate|Year|  Origin|
# +----+---------+-----------+----------+------+----------+----+--------+
# |46.6|        4|       86.0|        65|  2110|      17.9|  80|Japanese|
# |44.6|        4|       91.0|        67|  1850|      13.8|  80|Japanese|
# |44.3|        4|       90.0|        48|  2085|      21.7|  80|European|
# |44.0|        4|       97.0|        52|  2130|      24.6|  82|European|
# |43.4|        4|       90.0|        48|  2335|      23.7|  80|European|
# +----+---------+-----------+----------+------+----------+----+--------+
# only showing top 5 rows

# %% [markdown]
# ### Task 5 - Print the number of cars in each Origin

# %%
#your code goes here
df.select("Origin").show(2)
# Out:
# +--------+
# |  Origin|
# +--------+
# |Japanese|
# |Japanese|
# +--------+
# only showing top 2 rows

# %%
df.groupBy('Origin').count().orderBy('count').show()
# Out:
# +--------+-----+
# |  Origin|count|
# +--------+-----+
# |    null|    1|
# |European|   70|
# |Japanese|   88|
# |American|  247|
# +--------+-----+

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use  df.groupBy
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df.groupBy('Origin').count().orderBy('count').show()
# ```
#
# </details>

# %% [markdown]
# ### Task 6 - Print the total number of rows in the dataset

# %%
#your code goes here
rowcount1 = df.count() #TODO
print(rowcount1)
# Out:
# 406

# %% [markdown]
# ### Task 7 - Drop all the duplicate rows from the dataset

# %%
#your code goes here
df= df.dropDuplicates()

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use  df.dropDuplicates
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df = df.dropDuplicates()
# ```
#
# </details>

# %% [markdown]
# ### Task 8 - Print the total number of rows in the dataset

# %%
#your code goes here
rowcount2 = df.count() #TODO
print(rowcount2)
# Out:
# [Stage 9:======================================================>(199 + 1) / 200]
# 392

# %% [markdown]
# ### Task 9 - Drop all the rows that contain null values from the dataset

# %%
#your code goes here
df = df.dropna()

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use df.dropna
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df=df.dropna()
# ```
#
# </details>

# %% [markdown]
# ### Task 10 - Print the total number of rows in the dataset

# %%
#your code goes here
rowcount3 = df.count() #TODO
print(rowcount3)
# Out:
# [Stage 12:=================================================>   (186 + 10) / 200]
# 385

# %% [markdown]
# ### Task 11 - Rename the column "Engine Disp" to "Engine_Disp"Drop

# %%
#your code goes here

df = df.withColumnRenamed("Engine Disp","Engine_Disp")  #TODO

# %%
df.show(5)
# Out:
# +----+---------+-----------+----------+------+----------+----+--------+
# | MPG|Cylinders|Engine_Disp|Horsepower|Weight|Accelerate|Year|  Origin|
# +----+---------+-----------+----------+------+----------+----+--------+
# |24.0|        4|      134.0|        96|  2702|      13.5|  75|Japanese|
# |18.0|        6|      250.0|        88|  3139|      14.5|  71|American|
# |29.0|        4|       68.0|        49|  1867|      19.5|  73|European|
# |22.4|        6|      231.0|       110|  3415|      15.8|  81|American|
# |20.5|        6|      231.0|       105|  3425|      16.9|  77|American|
# +----+---------+-----------+----------+------+----------+----+--------+
# only showing top 5 rows

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use df.withColumnRenamed
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df = df.withColumnRenamed("Engine Disp","Engine_Disp")
# ```
#
# </details>

# %% [markdown]
# ### Task 12 - Save the dataframe in parquet format, name the file as "mpg-cleaned.parquet"

# %%
#your code goes he
df.write.mode("overwrite").parquet("mpg-cleaned.parquet")
# Out:
# [Stage 19:=======>                                               (28 + 8) / 200]23/12/19 18:28:19 WARN hadoop.MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use df.write.parquet
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df.write.parquet("mpg-cleaned.parquet")
# ```
#
# </details>

# %%
# !ls -1 mpg-cleaned.parque.show(3)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `ls -1 mpg-cleaned.parque.show(3)'

# %% [markdown]
# #### Part 1 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 1 - Evaluation")

print("Total rows = ", rowcount1)
print("Total rows after dropping duplicate rows = ", rowcount2)
print("Total rows after dropping duplicate rows and rows with null values = ", rowcount3)
print("Renamed column name = ", df.columns[2])

import os

print("mpg-cleaned.parquet exists :", os.path.isdir("mpg-cleaned.parquet"))
# Out:
# Part 1 - Evaluation
# Total rows =  406
# Total rows after dropping duplicate rows =  392
# Total rows after dropping duplicate rows and rows with null values =  385
# Renamed column name =  Engine_Disp
# mpg-cleaned.parquet exists : True

# %% [markdown]
# ## Part - 2 Machine Learning Pipeline creation

# %% [markdown]
# ### Task 1 - Load data from "mpg-cleaned.parquet" into a dataframe

# %%
#your code goes here

df = spark.read.csv("mpg-cleaned.parquet") #TODO
rowcount4 = df #TODO

# %%
# !!ls -l mpg-cleaned.parquet.show(5)
# Out:
# ["/bin/bash: -c: line 0: syntax error near unexpected token `('",
#  "/bin/bash: -c: line 0: `ls -l mpg-cleaned.parquet.show(5)'"]

# %%
#show top 5 rows
#your code goes here
rowcount4.show(5)
# Out:
# +--------------------+
# |                 _c0|
# +--------------------+
# |PAR1`HL...|
# |                :|
# |                9|
# | $3@�0@|
# |  $^@�u@DH|
# +--------------------+
# only showing top 5 rows

# %%
#print the schema of the dataframe
#your code goes here
df.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)

# %% [markdown]
# ### Task 2 - Define the StringIndexer pipeline stage

# %%
# Stage - 1 Using StringIndexer convert the string column "Origin" into "OriginIndex"
indexer = StringIndexer(inputCol="Origin", outputCol="OriginIndex") #TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use StringIndexer class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# indexer = StringIndexer(inputCol="Origin", outputCol="OriginIndex")
# ```
#
# </details>

# %% [markdown]
# ### Task 3 - Define the VectorAssembler pipeline stage

# %%
# Stage 2 - assemble the input columns 'Cylinders','Engine_Disp','Horsepower','Weight','Accelerate','Year' into a single column "features"
assembler = VectorAssembler(inputCols=['Cylinders','Engine_Disp','Horsepower','Weight','Accelerate','Year'], outputCol="features") #TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the VectorAssembler class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# assembler = VectorAssembler(inputCols=['Cylinders','Engine_Disp','Horsepower','Weight','Accelerate','Year'], outputCol="features")
# ```
#
# </details>

# %% [markdown]
# ### Task 4 - Define the StandardScaler pipeline stage

# %%
# Stage 3 - scale the "features" using standard scaler and store in "scaledFeatures" column
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures") #TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the StandardScaler class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures")
#
# ```
#
# </details>

# %% [markdown]
# ### Task 5 - Define the StandardScaler pipeline stage

# %%
# Stage 4 - Create a LinearRegression stage to predict
lr = LinearRegression(featuresCol="features", labelCol="MPG") #TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the LinearRegression class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# lr = LinearRegression(featuresCol="features", labelCol="MPG")
# ```
#
# </details>

# %% [markdown]
# ### Task 6 - Build the pipeline

# %%
# Build a pipeline using the above four stages

pipeline = Pipeline(stages=[indexer,assembler, scaler,lr]) #TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the Pipeline class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# pipeline = Pipeline(stages=[indexer,assembler, scaler, lr])
# ```
#
# </details>

# %% [markdown]
# ### Task 7 - Split the data

# %%
# Split the data into training and testing sets with 70:30 split. Use 42 as seed
(trainingData, testingData) = df.randomSplit([0.7, 0.3], seed=42) #TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the randomSplit method
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# (trainingData, testingData) = df.randomSplit([0.7, 0.3], seed=42)
# ```
#
# </details>

# %% [markdown]
# ### Task 8 - Fit the pipeline

# %%
from pyspark.sql import SparkSession

# %%
# Fit the pipeline using the training data

pipelineModel = pipeline.fit(trainingData)  #TOD0
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~/spark-2.4.3/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# ~/spark-2.4.3/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o61.fit.
# : java.lang.IllegalArgumentException: Field "Origin" does not exist.
# Available fields: _c0
# 	at org.apache.spark.sql.types.StructType$$anonfun$apply$1.apply(StructType.scala:274)
# 	at org.apache.spark.sql.types.StructType$$anonfun$apply$1.apply(StructType.scala:274)
# 	at scala.collection.MapLike$class.getOrElse(MapLike.scala:128)
# 	at scala.collection.AbstractMap.getOrElse(Map.scala:59)
# 	at org.apache.spark.sql.types.StructType.apply(StructType.scala:273)
# 	at org.apache.spark.ml.feature.StringIndexerBase$class.validateAndTransformSchema(StringIndexer.scala:85)
# 	at org.apache.spark.ml.feature.StringIndexer.validateAndTransformSchema(StringIndexer.scala:109)
# 	at org.apache.spark.ml.feature.StringIndexer.transformSchema(StringIndexer.scala:152)
# 	at org.apache.spark.ml.PipelineStage.transformSchema(Pipeline.scala:74)
# 	at org.apache.spark.ml.feature.StringIndexer.fit(StringIndexer.scala:135)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:745)
#
#
# During handling of the above exception, another exception occurred:
#
# IllegalArgumentException                  Traceback (most recent call last)
# /tmp/ipykernel_80/3038007703.py in <module>
#       1 # Fit the pipeline using the training data
#       2
# ----> 3 pipelineModel = pipeline.fit(trainingData)  #TOD0
#
# ~/spark-2.4.3/python/pyspark/ml/base.py in fit(self, dataset, params)
#     130                 return self.copy(params)._fit(dataset)
#     131             else:
# --> 132                 return self._fit(dataset)
#     133         else:
#     134             raise ValueError("Params must be either a param map or a list/tuple of param maps, "
#
# ~/spark-2.4.3/python/pyspark/ml/pipeline.py in _fit(self, dataset)
#     107                     dataset = stage.transform(dataset)
#     108                 else:  # must be an Estimator
# --> 109                     model = stage.fit(dataset)
#     110                     transformers.append(model)
#     111                     if i < indexOfLastEstimator:
#
# ~/spark-2.4.3/python/pyspark/ml/base.py in fit(self, dataset, params)
#     130                 return self.copy(params)._fit(dataset)
#     131             else:
# --> 132                 return self._fit(dataset)
#     133         else:
#     134             raise ValueError("Params must be either a param map or a list/tuple of param maps, "
#
# ~/spark-2.4.3/python/pyspark/ml/wrapper.py in _fit(self, dataset)
#     293
#     294     def _fit(self, dataset):
# --> 295         java_model = self._fit_java(dataset)
#     296         model = self._create_model(java_model)
#     297         return self._copyValues(model)
#
# ~/spark-2.4.3/python/pyspark/ml/wrapper.py in _fit_java(self, dataset)
#     290         """
#     291         self._transfer_params_to_java()
# --> 292         return self._java_obj.fit(dataset._jdf)
#     293
#     294     def _fit(self, dataset):
#
# ~/spark-2.4.3/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ~/spark-2.4.3/python/pyspark/sql/utils.py in deco(*a, **kw)
#      77                 raise QueryExecutionException(s.split(': ', 1)[1], stackTrace)
#      78             if s.startswith('java.lang.IllegalArgumentException: '):
# ---> 79                 raise IllegalArgumentException(s.split(': ', 1)[1], stackTrace)
#      80             raise
#      81     return deco
#
# IllegalArgumentException: 'Field "Origin" does not exist.\nAvailable fields: _c0'

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the pipeline.fit method
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# pipelineModel = pipeline.fit(trainingData)
# ```
#
# </details>

# %% [markdown]
# #### Part 2 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 2 - Evaluation")
print("Total rows = ", rowcount4)
ps = [str(x).split("_")[0] for x in pipeline.getStages()]

print("Pipeline Stage 1 = ", ps[0])
print("Pipeline Stage 2 = ", ps[1])
print("Pipeline Stage 3 = ", ps[2])

print("Label column = ", lr.getLabelCol())
# Out:
# Part 2 - Evaluation
# Total rows =  DataFrame[_c0: string]
# Pipeline Stage 1 =  StringIndexer
# Pipeline Stage 2 =  VectorAssembler
# Pipeline Stage 3 =  StandardScaler
# Label column =  MPG

# %% [markdown]
# ## Part 3 - Model Evaluation

# %% [markdown]
# ### Task 1 - Predict using the model

# %%
# Make predictions on testing data
predictions = pipelineModel.transform(testingData) #TODO
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_101/893774535.py in <module>
#       1 # Make predictions on testing data
# ----> 2 predictions = pipelineModel.transform(testingData) #TODO
#
# NameError: name 'pipelineModel' is not defined

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the transform method of the model
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# predictions = pipelineModel.transform(testingData)
# ```
#
# </details>

# %% [markdown]
# ### Task 2 - Print the MSE

# %%
#Your code goes here

evaluator = #TODO
mse = #TODO
print(mse)

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the RegressionEvaluator
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# from pyspark.ml.evaluation import RegressionEvaluator
#
# evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="mse")
# mse = evaluator.evaluate(predictions)
# print(mse)
#
# ```
#
# </details>

# %% [markdown]
# ### Task 3 - Print the MAE

# %%
#Your code goes here

evaluator = #TODO
mae = #TODO
print(mae)

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the RegressionEvaluator
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="mae")
# mae = evaluator.evaluate(predictions)
# print(mae)
#
# ```
#
# </details>

# %% [markdown]
# ### Task 4 - Print the R-Squared(R2)

# %%
#Your code goes here

evaluator = #TODO
r2 = #TODO
print(r2)

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the RegressionEvaluator
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="r2")
# r2 = evaluator.evaluate(predictions)
# print(r2)
# ```
#
# </details>

# %% [markdown]
# #### Part 3 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 3 - Evaluation")

print("Mean Squared Error = ", round(mse,2))
print("Mean Absolute Error = ", round(mae,2))
print("R Squared = ", round(r2,2))

lrModel = pipelineModel.stages[-1]

print("Intercept = ", round(lrModel.intercept,2))

# %% [markdown]
# ## Part 4 - Model persistance

# %% [markdown]
# ### Task 1 - Save the model to the path "Practice_Project"

# %%
# Save the pipeline model
# your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the model.write().save method
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# pipelineModel.write().save("Practice_Project")
# ```
#
# </details>

# %% [markdown]
# ### Task 2 - Load the model from the path "Practice_Project"

# %%
# Load the pipeline model
# your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the load method of the model
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# loadedPipelineModel = PipelineModel.load("Practice_Project")
# ```
#
# </details>

# %% [markdown]
# ### Task 3 - Make predictions using the loaded model on the test data

# %%
# Use the loaded pipeline model for predictions
# your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the transform method
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# predictions = loadedPipelineModel.transform(testingData)
# ```
#
# </details>

# %% [markdown]
# ### Task 4 - Show the predictions

# %%
# your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the the select method of the dataframe
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# predictions.select("MPG","prediction").show()
# ```
#
# </details>

# %% [markdown]
# #### Part 4 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 4 - Evaluation")

loadedmodel = loadedPipelineModel.stages[-1]
totalstages = len(loadedPipelineModel.stages)
inputcolumns = loadedPipelineModel.stages[1].getInputCols()

print("Number of stages in the pipeline = ", totalstages)
for i,j in zip(inputcolumns, loadedmodel.coefficients):
    print(f"Coefficient for {i} is {round(j,4)}")

# %% [markdown]
# ### Task 5 - Stop Spark Session

# %%
spark.stop()

# %% [markdown]
# Congratulations!! you have successfully finished the practice project.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Ramesh Sannareddy](https://www.linkedin.com/in/rsannareddy/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMBD0231ENSkillsNetwork866-2023-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-05-26|0.1|Ramesh Sannareddy|Initial Version Created|

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.
